# %%
#作業1
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y,'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title('Assume we habe data points (And the prediction)')
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y-yp))/len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)
print('The Mean absolute error is %.3f' %(MAE))
# Out:
# The Mean absolute error is 12.095

# %%
def mean_square_error(y, yp):
    mse = MSE = sum((y-yp) ** 2)/len(y)
    return mse
MSE = mean_square_error(y, y_hat)
print('The Mean Square Error is %.3f' %(MSE))
# Out:
# The Mean Square Error is 216.100

# %% [markdown]
# #作業2
# 我找的為Cardiovascular Disease dataset的dataset
# 1. 你選的這組資料為何重要
# 心血管疾病包含廣範，包括心肌梗塞，心臟衰竭，中風等，每年死亡人數佔台灣十大死因的30%左右，其實跟癌症不相上下，若是從生理資訊以及生活型態中可以找出特徵，可以減少心血管疾病的可能
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 此資料提供者是Svetlana Ulianova，他是加拿大Ryerson University大學的學生
#
# 3. 蒐集而來的資料型態為何
# 資料分成實驗數據，詢問受測者，而有數字型態(年齡，血壓，血糖數據)，邏輯(有無抽煙，有無心血管疾病)
#
# 4. 這組資料想解決的問題如何評估
# 我個人會想要利用此資料來評估資料內的內容來預測是否會獲得心血管疾病，因此若要評估，則會透過建立的模型預測之後，看實際預測的準確率，以及type I error, type II error的比例

# %% [markdown]
# #作業3
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# a.車子出去漫無目的亂繞
# b.時間浪費以及油錢浪費
# 若能有效知道客人叫車頻繁時間，交通路況，應該可以評估較佳的出車/路程模型
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 客人叫車較頻繁的時間，可以建置後端系統詳細記載現行每位客人乘車起始到結束的時間，並且其路徑也可一併紀錄，而交通狀況可以藉由google maps統計不同路段的尖峰離峰時間所需要車程
#
# 3. 蒐集而來的資料型態為何
# 至少需要時間(以分鐘為單位)，路程距離(以公尺為單位)，塞車狀況(順暢到賭塞可以分為4個等級)
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# a.每單位時間內所帶進收益
# b.每個時段空車/有載客的比例
